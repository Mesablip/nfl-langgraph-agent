# %%
import nfl_data_py as nfl

pbp = nfl.import_pbp_data([2020, 2021, 2022, 2023, 2024, 2025])
rosters = nfl.import_weekly_rosters([2020, 2021, 2022, 2023, 2024, 2025])
# Out:
# 2020 done.
# 2021 done.
# 2022 done.
# 2023 done.
# 2024 done.
# 2025 done.
# Downcasting floats.

# %%
rosters = nfl.import_weekly_rosters([2020, 2021, 2022, 2023, 2024, 2025])

# %%
rosters.status.unique()
# Out:
# array(['UFA', 'ACT', 'RES', 'INA', 'DEV', 'EXE', 'CUT', 'NWT', 'RSR',
#        'TRC', 'TRD', 'SUS', 'PUP', 'RFA', 'TRT', 'RSN', 'RET', 'E01',
#        'E14'], dtype=object)

# %%
rosters_clean = rosters[rosters.status.isin(['ACT', 'RES', 'INA', 'SUS', 'PUP'])]

# %%
import sqlite3
conn = sqlite3.connect("nfl.db")

# %%
pbp.to_sql("play_by_play", conn, if_exists="replace", index=False)
# Out:
# 294989

# %%
rosters_clean.to_sql("weekly_rosters", conn, if_exists="replace", index=False)
# Out:
# 216720

# %%
import pandas as pd

# %%
for x in pbp.columns:
    print(x)
# Out:
# play_id
# game_id
# old_game_id_x
# home_team
# away_team
# season_type
# week
# posteam
# posteam_type
# defteam
# side_of_field
# yardline_100
# game_date
# quarter_seconds_remaining
# half_seconds_remaining
# game_seconds_remaining
# game_half
# quarter_end
# drive
# sp
# qtr
# down
# goal_to_go
# time
# yrdln
# ydstogo
# ydsnet
# desc
# play_type
# yards_gained
# shotgun
# no_huddle
# qb_dropback
# qb_kneel
# qb_spike
# qb_scramble
# pass_length
# pass_location
# air_yards
# yards_after_catch
# run_location
# run_gap
# field_goal_result
# kick_distance
# extra_point_result
# two_point_conv_result
# home_timeouts_remaining
# away_timeouts_remaining
# timeout
# timeout_team
# td_team
# td_player_name
# td_player_id
# posteam_timeouts_remaining
# defteam_timeouts_remaining
# total_home_score
# total_away_score
# posteam_score
# defteam_score
# score_differential
# posteam_score_post
# defteam_score_post
# score_differential_post
# no_score_prob
# opp_fg_prob
# opp_safety_prob
# ...

# %%
pd.read_sql("SELECT passer_player_id, passer_player_name, passing_yards FROM play_by_play WHERE season = 2024 AND passer_player_id IS NOT NULL LIMIT 5", conn)
# Out:
#   passer_player_id passer_player_name  passing_yards
# 0       00-0035228           K.Murray           22.0
# 1       00-0035228           K.Murray            9.0
# 2       00-0035228           K.Murray            8.0
# 3       00-0035228           K.Murray            NaN
# 4       00-0035228           K.Murray            NaN

# %%
pd.read_sql("SELECT * FROM weekly_rosters WHERE season = 2024", conn)
# Out:
#        season team position depth_chart_position  jersey_number status  \
# 0        2024  NYJ       QB                   QB            8.0    ACT
# 1        2024  NYJ       QB                   QB            8.0    ACT
# 2        2024  NYJ       QB                   QB            8.0    ACT
# 3        2024  NYJ       QB                   QB            8.0    ACT
# 4        2024  NYJ       QB                   QB            8.0    ACT
# ...       ...  ...      ...                  ...            ...    ...
# 36401    2024   NO       DL                   DT           76.0    RES
# 36402    2024   NO       DL                   DT           76.0    RES
# 36403    2024   NO       DL                   DT           76.0    RES
# 36404    2024   NO       DL                   DT           76.0    RES
# 36405    2024   NO       DL                   DT           76.0    RES
#
#            player_name first_name last_name           birth_date  ...  \
# ...
